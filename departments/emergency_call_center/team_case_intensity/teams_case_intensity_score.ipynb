# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import duckdb

import datetime as dt
import os
from concurrent.futures import ThreadPoolExecutor

# %%
con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")

# %% [markdown]
# **PARQUET FILE CREATION STARTED SKIP THIS AREA**

# %%
path_2020= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2020\total\\"

# %%
path_2021= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2021\total\\"

# %%
path_2017= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2020\total\\"
path_2018= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2018\total\\"
path_2019= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2019\total\\"
path_2022= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2022\total\\"
path_2023= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2023\total\\"
path_2024= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2024\total\\"
path_2025= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2025\monthly\\"

# %%
paths= [path_2017, path_2018, path_2019, path_2020, path_2021, path_2022, path_2023, path_2024, path_2025]

# %%
path_2018

# %%
for file in os.listdir(path_2022):
    if file.endswith('.csv'):
        file_path = os.path.join(path_2022, file)
        print(f"Processing {file_path}")
        # Read the Excel file and convert to Parquet
        con.execute(f"""
            COPY (
                SELECT * FROM read_csv('{file_path}', strict_mode=false,max_line_size=10000000,all_varchar=true)
            ) TO '{file_path}.parquet' (FORMAT 'parquet')
        """)

# %%
con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")

for file in os.listdir(path_2024):
    if file.endswith('.csv'):
        file_path = os.path.join(path_2024, file)
        print(f"Processing {file_path}")
        # Read the Excel file and convert to Parquet
        con.execute(f"""
            COPY (
                SELECT * FROM read_csv('{file_path}', strict_mode=false,max_line_size=10000000,all_varchar=true)
            ) TO '{file_path}.parquet' (FORMAT 'parquet')
        """)

# %%
os.listdir(path_2020)

# %%
files = []
for data in os.listdir(path_2017):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2017, data))
for data in os.listdir(path_2018):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2018, data))
for data in os.listdir(path_2019):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2019, data))
for data in os.listdir(path_2020):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2020, data))
for data in os.listdir(path_2021):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2021, data))
for data in os.listdir(path_2022):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2022, data))
for data in os.listdir(path_2023):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2023, data))
for data in os.listdir(path_2024):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2024, data))
for data in os.listdir(path_2025):
  if data.endswith(".xlsx"):
    files.append(os.path.join(path_2025, data))

import duckdb
import pandas as pd
con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")
dfs= []
for file_path in files:

  # Step 1: Get all sheet names
  sheet_names = pd.ExcelFile(file_path).sheet_names

  # Step 2: Check number of rows in each sheet
  xls = pd.ExcelFile(file_path)
  max_rows = 0
  largest_sheet = None

  for sheet in sheet_names:
      temp_df = xls.parse(sheet, nrows=1000)  # read only first 1000 rows for speed
      row_count = temp_df.shape[0]
      if row_count > max_rows:
          max_rows = row_count
          largest_sheet = sheet

  # Step 3: Read the largest sheet
  con.execute(f"""
      COPY (SELECT * FROM read_xlsx('{file_path}', sheet='{largest_sheet}', all_varchar=true)
      ) TO '{file_path}.parquet' (FORMAT 'parquet')""")
  print(f"{file_path}.parquet created successfully")

# %%
files = []

for data in os.listdir(path_2022):
  if data.endswith(".csv"):
    files.append(os.path.join(path_2022, data))

for data in os.listdir(path_2024):
  if data.endswith(".csv"):
    files.append(os.path.join(path_2024, data))


con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")
dfs= []
for file_path in files:

  # Step 1: Get all sheet names
  sheet_names = pd.ExcelFile(file_path).sheet_names

  # Step 2: Check number of rows in each sheet
  xls = pd.ExcelFile(file_path)
  max_rows = 0
  largest_sheet = None

  for sheet in sheet_names:
      temp_df = xls.parse(sheet, nrows=1000)  # read only first 1000 rows for speed
      row_count = temp_df.shape[0]
      if row_count > max_rows:
          max_rows = row_count
          largest_sheet = sheet

  # Step 3: Read the largest sheet
  con.execute(f"""
      COPY (SELECT * FROM read_csv('{file_path}', sheet='{largest_sheet}', all_varchar=true)
      ) TO '{file_path}.parquet' (FORMAT 'parquet')""")
  print(f"{file_path}.parquet created successfully")

# %%
#temp_df= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2022\total\2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ.xlsx.parquet")

# %%
# Function to handle both numeric and string date formats
def parse_date(x):
    if isinstance(x, (int, float)):
        # Assume it's an Excel date serial number
        try:
            # Using origin='1899-12-30' for Excel date serial numbers
            return pd.to_datetime(x, unit='d', origin='12-30-1899')
        except Exception as e:
            print(f"Error parsing numeric date {x}: {e}")
            return pd.NaT
    elif isinstance(x, str):
        # Try parsing as a string date with mixed format
        try:
            return pd.to_datetime(x, format='mixed', errors='coerce')
        except Exception as e:
            print(f"Error parsing string date {x}: {e}")
            return pd.NaT
    else:
        # Handle other data types like pd.NaT
        return pd.NaT

# Apply the custom parsing function
#temp_df["İhbar/Çağrı Tarihi"] = temp_df["İhbar/Çağrı Tarihi"].apply(parse_date)

# %%
temp_df= dataframes_2018_2019['2018 YILI AVRUPA']['İhbar/Çağrı Tarih Saat']

# %%
import duckdb
import pandas as pd
con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")

# %%
con.execute("""
    COPY (SELECT * FROM read_csv('C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2018\\total\\\\2018 YILI AVRUPA.csv', all_varchar=true)
    ) TO 'C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2018\\total\\\\2018 YILI AVRUPA.parquet' (FORMAT 'parquet')""")
print("C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2018\\total\\\\2018 YILI AVRUPA.parquet created successfully")

# %%
con.execute("""
    COPY (SELECT * FROM read_csv('C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2023\\total\\2023 AVR BİRLEŞTİRİLMİŞ MAHALLE DEFTERİ.csv', all_varchar=true, strict_mode=false, max_line_size=100000000)
    ) TO 'C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2023\\total\\2023 AVR BİRLEŞTİRİLMİŞ MAHALLE DEFTERİ.csv.parquet' (FORMAT 'parquet')""")
print("C:\\Users\\mkaya\\OneDrive\\Masaüstü\\istanbul112_hidden\\data\\case_reports\\europe\\2023\\total\\2023 AVR BİRLEŞTİRİLMİŞ MAHALLE DEFTERİ.csv.parquet created successfully")

# %%
save_path= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2020_2021\\"

# %%
files

# %%
files_2 = []
for data in os.listdir(path_2020):
  if data.endswith(".xlsx"):
    files_2.append(data.replace(".xlsx", ".parquet"))
for data in os.listdir(path_2021):
  if data.endswith(".xlsx"):
    files_2.append( data.replace(".xlsx", ".parquet"))

# %%
files_2

# %%
count= 0
for df in dfs:
  df = df.astype({col: str for col in df.columns})
  df.to_parquet(save_path + files_2[count] )
  count += 1

# %%
df_2022_jan= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\OCAK 2022 AVR DEFTERİ - MAHALLE BAZLI ÇALIŞMA SON.parquet")

# %%
df_2023_jan= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\1-OCAK 2023 7 KALEM MAHALLE DEFTER AVRUPA.parquet")

# %%
df_2024_jan= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\1-OCAK 2024 AVR ASOS TANIDÖNÜŞTÜRÜLMÜŞ DEFTER.parquet")

# %%
df_2025_jan= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\1-OCAK 2025 AVR ASOS TANI DÖNÜŞTÜRÜLMÜŞ DEFTER.parquet")

# %%
[col for col in df_2025_jan.columns if col not in df_2022_jan.columns]

# %%
df_2022_jan['Olay Yeri Varış']

# %% [markdown]
# **PARQUET FILE CREATION ENDED YOU CAN CONTINUE FROM HERE**

# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor

# %%
dataframes_2017= {}
dataframes_2018_2019= {}
dataframes_2020_2021= {}
dataframes_2022_2023= {}
dataframes_2024_2025= {}

# %%
case_files_2017= os.listdir(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2017\\")
case_files_2018_2019= os.listdir(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2018_2019\\")
case_files_2020_2021= os.listdir(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2020_2021\\")
case_files_2022_2023= os.listdir(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\\")
case_files_2024_2025= os.listdir(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\\")

# %%
case_files_2017= [file for file in case_files_2017 if file.endswith(".parquet")]
case_files_2018_2019= [file for file in case_files_2018_2019 if file.endswith(".parquet")]
case_files_2020_2021= [file for file in case_files_2020_2021 if file.endswith(".parquet")]
case_files_2022_2023= [file for file in case_files_2022_2023 if file.endswith(".parquet")]
case_files_2024_2025= [file for file in case_files_2024_2025 if file.endswith(".parquet")]

# %%
case_files_2022_2023

# %%
for file in case_files_2017:
  dataframes_2017[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2017\\" + file)
  print(file, ' has been read')
for file in case_files_2018_2019:
  dataframes_2018_2019[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2018_2019\\" + file)
  print(file, ' has been read')
for file in case_files_2020_2021:
  dataframes_2020_2021[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2020_2021\\" + file)
  print(file, ' has been read')
for file in case_files_2022_2023:
  dataframes_2022_2023[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\\" + file)
  print(file, ' has been read')
for file in case_files_2024_2025:
  dataframes_2024_2025[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\\" + file)
  print(file, ' has been read')

# %%
for file in case_files_2018_2019:
  dataframes_2018_2019[file.replace(".parquet", "")]= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2018_2019\\" + file)
  print(file, ' has been read')

# %%
dataframes_2022_2023["2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ"]["İhbar/Çağrı Tarihi"].value_counts()

# %%
dataframes_2018_2019['2018 YILI AVRUPA']['İhbar Tarihi'].value_counts().head(60)

# %%
dataframes_2018_2019["2019 YILI ASOS AVR"].columns

# %%
sorted(list(dataframes_2022_2023.keys()))

# %%
for key in dataframes_2020_2021.keys():
  print(key, ' : ',dataframes_2020_2021[key].shape)

# %%
[col for col in dataframes_2020_2021["2020 YILI TEMMUZ-ARALIK ASOS DEFTERİ"].columns if col not in dataframes_2020_2021["2020 YILI OCAK-HAZİRAN AYLARI DEFTER"].columns]

# %%
dataframes_2020_2021["2020 YILI OCAK-HAZİRAN AYLARI DEFTER"].rename(columns={"ICD10 TANI \nADI":"ICD10 TANI\nADI"}, inplace=True)

# %%
dataframes_2020_2021["2020 YILI OCAK-HAZİRAN AYLARI DEFTER"]

# %%
dataframes_2018_2019["2019 YILI ASOS AVR"]

# %%
for key in dataframes_2017.keys():
  for col in dataframes_2017[key].columns:
    if col=="ICD10 TANI \nADI":
      dataframes_2017[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=='Vaka Veriliş':
      dataframes_2017[key].rename(columns={'Vaka Veriliş':'Vaka Veriliş Tarih Saat'}, inplace=True)
    if col == 'Ulaşım Sn':
      dataframes_2017[key].rename(columns={'Ulaşım Sn':'Ulaşım Sn\n(Olay Yeri Varış Tarihi - Çağrı Tarihi)'}, inplace=True)
    if col == 'İhbar Tarihi':
      dataframes_2017[key].rename(columns={'İhbar Tarihi':'İhbar/Çağrı Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Varış':
      dataframes_2017[key].rename(columns={'Olay Yeri Varış':'Olay Yeri Varış Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Ayrılış':
      dataframes_2017[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)
    if col == 'Hastaneye Varış':
      dataframes_2017[key].rename(columns={'Hastaneye Varış':'Hastaneye Varış Tarih Saat'}, inplace=True)
    if col == 'Hastaneden Ayrılış':
      dataframes_2017[key].rename(columns={'Hastaneden Ayrılış':'Hastaneden Ayrılış Tarih Saat'}, inplace=True)
    if col == 'İstasyona Dönüş':
      dataframes_2017[key].rename(columns={'İstasyona Dönüş':'İstasyona Dönüş Tarih Saat'}, inplace=True)
for key in dataframes_2018_2019.keys():
  for col in dataframes_2018_2019[key].columns:
    if col=="ICD10 TANI \nADI":
      dataframes_2018_2019[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=="ICD10 TANI \nADI":
      dataframes_2018_2019[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=='Vaka Veriliş':
      dataframes_2018_2019[key].rename(columns={'Vaka Veriliş':'Vaka Veriliş Tarih Saat'}, inplace=True)
    if col == 'Ulaşım Sn':
      dataframes_2018_2019[key].rename(columns={'Ulaşım Sn':'Ulaşım Sn\n(Olay Yeri Varış Tarihi - Çağrı Tarihi)'}, inplace=True)
    if col == 'İhbar Tarihi':
      dataframes_2018_2019[key].rename(columns={'İhbar Tarihi':'İhbar/Çağrı Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Varış':
      dataframes_2018_2019[key].rename(columns={'Olay Yeri Varış':'Olay Yeri Varış Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Ayrılış':
      dataframes_2018_2019[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)
    if col == 'Hastaneye Varış':
      dataframes_2018_2019[key].rename(columns={'Hastaneye Varış':'Hastaneye Varış Tarih Saat'}, inplace=True)
    if col == 'Hastaneden Ayrılış':
      dataframes_2018_2019[key].rename(columns={'Hastaneden Ayrılış':'Hastaneden Ayrılış Tarih Saat'}, inplace=True)
    if col == 'İstasyona Dönüş':
      dataframes_2018_2019[key].rename(columns={'İstasyona Dönüş':'İstasyona Dönüş Tarih Saat'}, inplace=True)
for key in dataframes_2020_2021.keys():
  for col in dataframes_2020_2021[key].columns:
    if col=="ICD10 TANI \nADI":
      dataframes_2020_2021[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=='Vaka Veriliş':
      dataframes_2020_2021[key].rename(columns={'Vaka Veriliş':'Vaka Veriliş Tarih Saat'}, inplace=True)
    if col == 'Ulaşım Sn':
      dataframes_2020_2021[key].rename(columns={'Ulaşım Sn':'Ulaşım Sn\n(Olay Yeri Varış Tarihi - Çağrı Tarihi)'}, inplace=True)
    if col == 'İhbar Tarihi':
      dataframes_2020_2021[key].rename(columns={'İhbar Tarihi':'İhbar/Çağrı Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Varış':
      dataframes_2020_2021[key].rename(columns={'Olay Yeri Varış':'Olay Yeri Varış Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Ayrılış':
      dataframes_2020_2021[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)
    if col == 'Hastaneye Varış':
      dataframes_2020_2021[key].rename(columns={'Hastaneye Varış':'Hastaneye Varış Tarih Saat'}, inplace=True)
    if col == 'Hastaneden Ayrılış':
      dataframes_2020_2021[key].rename(columns={'Hastaneden Ayrılış':'Hastaneden Ayrılış Tarih Saat'}, inplace=True)
    if col == 'İstasyona Dönüş':
      dataframes_2020_2021[key].rename(columns={'İstasyona Dönüş':'İstasyona Dönüş Tarih Saat'}, inplace=True)
for key in dataframes_2022_2023.keys():
  for col in dataframes_2022_2023[key].columns:
    if col=="ICD10 TANI \nADI":
      dataframes_2022_2023[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=='Vaka Veriliş':
      dataframes_2022_2023[key].rename(columns={'Vaka Veriliş':'Vaka Veriliş Tarih Saat'}, inplace=True)
    if col == 'Ulaşım Sn':
      dataframes_2022_2023[key].rename(columns={'Ulaşım Sn':'Ulaşım Sn\n(Olay Yeri Varış Tarihi - Çağrı Tarihi)'}, inplace=True)
    if col == 'İhbar Tarihi':
      dataframes_2022_2023[key].rename(columns={'İhbar Tarihi':'İhbar/Çağrı Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Varış':
      dataframes_2022_2023[key].rename(columns={'Olay Yeri Varış':'Olay Yeri Varış Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Ayrılış':
      dataframes_2022_2023[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)
    if col == 'Hastaneye Varış':
      dataframes_2022_2023[key].rename(columns={'Hastaneye Varış':'Hastaneye Varış Tarih Saat'}, inplace=True)
    if col == 'Hastaneden Ayrılış':
      dataframes_2022_2023[key].rename(columns={'Hastaneden Ayrılış':'Hastaneden Ayrılış Tarih Saat'}, inplace=True)
    if col=='İstasyona Dönüş':
      dataframes_2022_2023[key].rename(columns={'İstasyona Dönüş':'İstasyona Dönüş Tarih Saat'}, inplace=True)
for key in dataframes_2024_2025.keys():
  for col in dataframes_2024_2025[key].columns:
    if col=="ICD10 TANI \nADI":
      dataframes_2024_2025[key].rename(columns={'ICD10 TANI \nADI':'ICD10 TANI\nADI'}, inplace=True)
    if col=='Vaka Veriliş':
      dataframes_2024_2025[key].rename(columns={'Vaka Veriliş':'Vaka Veriliş Tarih Saat'}, inplace=True)
    if col == 'Ulaşım Sn':
      dataframes_2024_2025[key].rename(columns={'Ulaşım Sn':'Ulaşım Sn\n(Olay Yeri Varış Tarihi - Çağrı Tarihi)'}, inplace=True)
    if col == 'İhbar Tarihi':
      dataframes_2024_2025[key].rename(columns={'İhbar Tarihi':'İhbar/Çağrı Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Varış':
      dataframes_2024_2025[key].rename(columns={'Olay Yeri Varış':'Olay Yeri Varış Tarih Saat'}, inplace=True)
    if col == 'Olay Yeri Ayrılış':
      dataframes_2024_2025[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)
    if col == 'Hastaneye Varış':
      dataframes_2024_2025[key].rename(columns={'Hastaneye Varış':'Hastaneye Varış Tarih Saat'}, inplace=True)
    if col == 'Hastaneden Ayrılış':
      dataframes_2024_2025[key].rename(columns={'Hastaneden Ayrılış':'Hastaneden Ayrılış Tarih Saat'}, inplace=True)
    if col=='İstasyona Dönüş':
      dataframes_2024_2025[key].rename(columns={'İstasyona Dönüş':'İstasyona Dönüş Tarih Saat'}, inplace=True)

# %%
dataframes_2020_2021["2020 YILI OCAK-HAZİRAN AYLARI DEFTER"]["Olay Yeri Ayrılış Tarih Saat"].isna().sum()

# %%
for key in dataframes_2022_2023.keys():
  print(key, ' : ',dataframes_2022_2023[key].shape)

# %%
[col for col in dataframes_2022_2023["2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ"].columns if col not in dataframes_2022_2023['2023 AVR BİRLEŞTİRİLMİŞ MAHALLE DEFTERİ'].columns]

# %% [markdown]
# **SAVE PARQUET FILES**

# %%
save_path_0= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2017\\"
save_path_001= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2018_2019\\"
save_path_1= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2020_2021\\"
save_path_2= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\\"
save_path_3= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\\"

# %%
for key in dataframes_2017.keys():
  print(f"saving {key}")
  dataframes_2017[key].to_parquet(save_path_0 + key + ".parquet")
for key in dataframes_2018_2019.keys():
  print(f"saving {key}")
  dataframes_2018_2019[key].to_parquet(save_path_001 + key + ".parquet")
for key in dataframes_2020_2021.keys():
  print(f"saving {key}")
  dataframes_2020_2021[key].to_parquet(save_path_1 + key + ".parquet")
for key in dataframes_2022_2023.keys():
  dataframes_2022_2023[key].to_parquet(save_path_2 + key + ".parquet")
  print(f"saving {key}")
for key in dataframes_2024_2025.keys():
  print(f"saving {key}")
  dataframes_2024_2025[key].to_parquet(save_path_3 + key + ".parquet")

# %% [markdown]
# **CONTINUE CODING**

# %%
#ataframes_2024_2025['4-NİSAN 2025 AVR ASOS TANI DÖNÜŞTÜRÜLMÜŞ DEFTER'].head(1000).to_excel('test.xlsx')

# %%
print([col for col in dataframes_2024_2025['1-OCAK 2025 AVR ASOS TANI DÖNÜŞTÜRÜLMÜŞ DEFTER'].columns])

# %%
necessary_columns= ['KKM Protokol','Ekip No', 'İhbar/Çağrı Tarih Saat', 'Cinsiyet', 'Yeni Doğan', 'Yaş', 'Adli Vaka', 'Çağrı Nedeni', 'Sonuç', 'Nakledilen Hastane', 'ICD10 TANI\nADI', 'Triaj', 'Bilinç', 'Nabız', 'Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat', 'Olay Yeri Ayrılış Tarih Saat', 'Hastaneye Varış Tarih Saat', 'Hastaneden Ayrılış Tarih Saat', 'Müdahale Süresi Sn', 'Hastane Teslim Süresi Sn', 'Çıkış KM', 'Varış KM', 'Hastaneye Varış KM', 'Dönüş KM', 'Vakanın Enlemi', 'Vakanın Boylamı', 'Tansiyon', 'Glukoz', 'Ateş', 'SPO2', 'Solunum Değeri', 'Nabız Değeri']

# %%
dataframes_2020_2021['2020 YILI OCAK-HAZİRAN AYLARI DEFTER']

# %%
necessary_columns

# %%
columns_to_process= ['İhbar/Çağrı Tarih Saat','Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat','Olay Yeri Ayrılış Tarih Saat','Hastaneye Varış Tarih Saat','Hastaneden Ayrılış Tarih Saat']

# %%
all_datas= [dataframes_2018_2019,dataframes_2020_2021, dataframes_2022_2023, dataframes_2024_2025]

# %%
dataframes_2018_2019.keys()

# %%
"""for dataframe in all_datas:
  for key in dataframe.keys():
    print(f"Processing {key}")

    # Rename column if necessary
    if "Hastaneye Varış Saati\n" in dataframe[key].columns:
      dataframe[key].rename(columns={"Hastaneye Varış Saati\n": "Hastaneye Varış Saati"}, inplace=True)

    # Process 'İhbar/Çağrı Tarih Saat' or create it if needed
    if "İhbar/Çağrı Tarih Saat" not in dataframe[key].columns:
      print(f"Creating İhbar/Çağrı Tarih Saat for {key}")
      # First, apply the parse_date function to the original date column
      if 'İhbar/Çağrı Tarihi' in dataframe[key].columns and 'İhbar/Çağrı  Saati' in dataframe[key].columns:
        dataframe[key]["İhbar/Çağrı Tarihi"] = dataframe[key]["İhbar/Çağrı Tarihi"].apply(parse_date)
        # Convert time column to string, handling potential non-string types
        dataframe[key]['İhbar/Çağrı  Saati'] = dataframe[key]['İhbar/Çağrı  Saati'].astype(str)
        # Combine date and time columns, coercing errors
        dataframe[key]["İhbar/Çağrı Tarih Saat"] = pd.to_datetime(
            dataframe[key]['İhbar/Çağrı Tarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['İhbar/Çağrı  Saati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
          print(f"Warning: 'İhbar/Çağrı Tarihi' or 'İhbar/Çağrı  Saati' not found in {key}. Cannot create 'İhbar/Çağrı Tarih Saat'.")
    else:
        # If 'İhbar/Çağrı Tarih Saat' already exists, ensure it's in datetime format
        print(f"Converting İhbar/Çağrı Tarih Saat to datetime for {key}")
        dataframe[key]['İhbar/Çağrı Tarih Saat'] = pd.to_datetime(dataframe[key]['İhbar/Çağrı Tarih Saat'], errors='coerce')


    # Process 'Vaka Veriliş Tarih Saat'
    if "Vaka Veriliş Tarih Saat" not in dataframe[key].columns:
      print(f"Creating Vaka Veriliş Tarih Saat for {key}")
      if 'Vaka Veriliş\nTarihi' in dataframe[key].columns and 'Vaka Veriliş\nSaati' in dataframe[key].columns:
        dataframe[key]['Vaka Veriliş\nTarihi'] = dataframe[key]['Vaka Veriliş\nTarihi'].apply(parse_date)
        dataframe[key]['Vaka Veriliş\nSaati'] = dataframe[key]['Vaka Veriliş\nSaati'].astype(str)
        dataframe[key]["Vaka Veriliş Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Vaka Veriliş\nTarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['Vaka Veriliş\nSaati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
           print(f"Warning: 'Vaka Veriliş\\nTarihi' or 'Vaka Veriliş\\nSaati' not found in {key}. Cannot create 'Vaka Veriliş Tarih Saat'.")
    else:
        print(f"Converting Vaka Veriliş Tarih Saat to datetime for {key}")
        dataframe[key]['Vaka Veriliş Tarih Saat'] = pd.to_datetime(dataframe[key]['Vaka Veriliş Tarih Saat'], errors='coerce')


    # Process 'Olay Yeri Varış Tarih Saat'
    if "Olay Yeri Varış Tarih Saat" not in dataframe[key].columns:
      print(f"Creating Olay Yeri Varış Tarih Saat for {key}")
      if 'Olay Yeri Varış Tarihi' in dataframe[key].columns and 'Olay Yeri Varış Saati' in dataframe[key].columns:
        dataframe[key]['Olay Yeri Varış Tarihi'] = dataframe[key]['Olay Yeri Varış Tarihi'].apply(parse_date)
        dataframe[key]['Olay Yeri Varış Saati'] = dataframe[key]['Olay Yeri Varış Saati'].astype(str)
        dataframe[key]["Olay Yeri Varış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Olay Yeri Varış Tarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['Olay Yeri Varış Saati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
          print(f"Warning: 'Olay Yeri Varış Tarihi' or 'Olay Yeri Varış Saati' not found in {key}. Cannot create 'Olay Yeri Varış Tarih Saat'.")
    else:
        print(f"Converting Olay Yeri Varış Tarih Saat to datetime for {key}")
        dataframe[key]['Olay Yeri Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Varış Tarih Saat'], errors='coerce')

    # Process 'Olay Yeri Ayrılış Tarih Saat'
    if 'Olay Yeri Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Olay Yeri Ayrılış Tarih Saat for {key}")
      if 'Olay Yeri Ayrılış Tarihi' in dataframe[key].columns and 'Olay Yeri Ayrılış Saati' in dataframe[key].columns:
        dataframe[key]['Olay Yeri Ayrılış Tarihi'] = dataframe[key]['Olay Yeri Ayrılış Tarihi'].apply(parse_date)
        dataframe[key]['Olay Yeri Ayrılış Saati'] = dataframe[key]['Olay Yeri Ayrılış Saati'].astype(str)
        dataframe[key]["Olay Yeri Ayrılış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Olay Yeri Ayrılış Tarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['Olay Yeri Ayrılış Saati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
          print(f"Warning: 'Olay Yeri Ayrılış Tarihi' or 'Olay Yeri Ayrılış Saati' not found in {key}. Cannot create 'Olay Yeri Ayrılış Tarih Saat'.")
    else:
        print(f"Converting Olay Yeri Ayrılış Tarih Saat to datetime for {key}")
        dataframe[key]['Olay Yeri Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Ayrılış Tarih Saat'], errors='coerce')

    # Process 'Hastaneye Varış Tarih Saat'
    # Note the inconsistent column name 'Hastaneye varış Tarih Saat' found in the traceback
    if 'Hastaneye Varış Tarih Saat' not in dataframe[key].columns and 'Hastaneye varış Tarih Saat' in dataframe[key].columns:
         dataframe[key].rename(columns={'Hastaneye varış Tarih Saat':'Hastaneye Varış Tarih Saat'}, inplace=True)

    if 'Hastaneye Varış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Hastaneye Varış Tarih Saat for {key}")
      if 'Hastaneye Varış Tarihi' in dataframe[key].columns and 'Hastaneye Varış Saati' in dataframe[key].columns:
        dataframe[key]['Hastaneye Varış Tarihi'] = dataframe[key]['Hastaneye Varış Tarihi'].apply(parse_date)
        dataframe[key]['Hastaneye Varış Saati'] = dataframe[key]['Hastaneye Varış Saati'].astype(str)
        dataframe[key]["Hastaneye Varış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Hastaneye Varış Tarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['Hastaneye Varış Saati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
          print(f"Warning: 'Hastaneye Varış Tarihi' or 'Hastaneye Varış Saati' not found in {key}. Cannot create 'Hastaneye Varış Tarih Saat'.")
    else:
        print(f"Converting Hastaneye Varış Tarih Saat to datetime for {key}")
        dataframe[key]['Hastaneye Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneye Varış Tarih Saat'], errors='coerce')

    # Process 'Hastaneden Ayrılış Tarih Saat'
    if 'Hastaneden Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Hastaneden Ayrılış Tarih Saat for {key}")
      if 'Hastaneden Ayrılış Tarihi' in dataframe[key].columns and 'Hastaneden Ayrılış Saati' in dataframe[key].columns:
        dataframe[key]['Hastaneden Ayrılış Tarihi'] = dataframe[key]['Hastaneden Ayrılış Tarihi'].apply(parse_date)
        dataframe[key]['Hastaneden Ayrılış Saati'] = dataframe[key]['Hastaneden Ayrılış Saati'].astype(str)
        dataframe[key]["Hastaneden Ayrılış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Hastaneden Ayrılış Tarihi'].dt.strftime('%Y-%m-%d') + ' ' + dataframe[key]['Hastaneden Ayrılış Saati'],
            format='%Y-%m-%d %H:%M:%S', errors='coerce'
        )
      else:
          print(f"Warning: 'Hastaneden Ayrılış Tarihi' or 'Hastaneden Ayrılış Saati' not found in {key}. Cannot create 'Hastaneden Ayrılış Tarih Saat'.")
    else:
        print(f"Converting Hastaneden Ayrılış Tarih Saat to datetime for {key}")
        dataframe[key]['Hastaneden Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneden Ayrılış Tarih Saat'], errors='coerce')"""

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['İhbar/Çağrı Tarih Saat']= dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['İhbar/Çağrı Tarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['İhbar/Çağrı  Saati']

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['İhbar/Çağrı Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['İhbar/Çağrı Tarih Saat'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Vaka Veriliş Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Vaka Veriliş\nTarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Vaka Veriliş\nSaati'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Varış Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Varış Tarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Varış Saati'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Ayrılış Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Ayrılış Tarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Olay Yeri Ayrılış Saati'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneye Varış Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneye Varış Tarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneye Varış Saati\n'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneden Ayrılış Tarih Saat']= pd.to_datetime(dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneden Ayrılış Tarihi'] + ' ' + dataframes_2022_2023['2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ']['Hastaneden Ayrılış Saati'], format= '%d-%m-%Y %H:%M:%S')

# %%
dataframes_2022_2023['2023 AVR BİRLEŞTİRİLMİŞ MAHALLE DEFTERİ']['Hastaneye Varış Tarihi'].isna().sum()

# %%
for dataframe in all_datas:
  for key in dataframe.keys():
    print(f"Processing {key}")

    # Rename column if necessary
    if "Hastaneye Varış Saati\n" in dataframe[key].columns:
      dataframe[key].rename(columns={"Hastaneye Varış Saati\n": "Hastaneye Varış Saati"}, inplace=True)

    # Process 'İhbar/Çağrı Tarih Saat' or create it if needed
    if "İhbar/Çağrı Tarih Saat" not in dataframe[key].columns:
      print(f"Creating İhbar/Çağrı Tarih Saat for {key}")
      # First, apply the parse_date function to the original date column
      if 'İhbar/Çağrı Tarihi' in dataframe[key].columns and 'İhbar/Çağrı  Saati' in dataframe[key].columns:

        # Convert time column to string, handling potential non-string types
        dataframe[key]['İhbar/Çağrı  Saati'] = dataframe[key]['İhbar/Çağrı  Saati']
        # Combine date and time columns, coercing errors
        dataframe[key]["İhbar/Çağrı Tarih Saat"] = pd.to_datetime(
            dataframe[key]['İhbar/Çağrı Tarihi']+ ' ' + dataframe[key]['İhbar/Çağrı  Saati'],
            format='mixed'
        )
      else:
          print(f"Warning: 'İhbar/Çağrı Tarihi' or 'İhbar/Çağrı  Saati' not found in {key}. Cannot create 'İhbar/Çağrı Tarih Saat'.")
    else:
        # If 'İhbar/Çağrı Tarih Saat' already exists, ensure it's in datetime format
        print(f"Converting İhbar/Çağrı Tarih Saat to datetime for {key}")
        dataframe[key]['İhbar/Çağrı Tarih Saat'] = pd.to_datetime(dataframe[key]['İhbar/Çağrı Tarih Saat'], format= 'mixed')


    # Process 'Vaka Veriliş Tarih Saat'
    if "Vaka Veriliş Tarih Saat" not in dataframe[key].columns:
      print(f"Creating Vaka Veriliş Tarih Saat for {key}")
      if 'Vaka Veriliş\nTarihi' in dataframe[key].columns and 'Vaka Veriliş\nSaati' in dataframe[key].columns:
        dataframe[key]['Vaka Veriliş\nSaati'] = dataframe[key]['Vaka Veriliş\nSaati']
        dataframe[key]["Vaka Veriliş Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Vaka Veriliş\nTarihi'] + ' ' + dataframe[key]['Vaka Veriliş\nSaati'],
            format='mixed'
        )
      else:
           print(f"Warning: 'Vaka Veriliş\\nTarihi' or 'Vaka Veriliş\\nSaati' not found in {key}. Cannot create 'Vaka Veriliş Tarih Saat'.")
    else:
        print(f"Converting Vaka Veriliş Tarih Saat to datetime for {key}")
        dataframe[key]['Vaka Veriliş Tarih Saat'] = pd.to_datetime(dataframe[key]['Vaka Veriliş Tarih Saat'], format= 'mixed')


    # Process 'Olay Yeri Varış Tarih Saat'
    if "Olay Yeri Varış Tarih Saat" not in dataframe[key].columns:
      print(f"Creating Olay Yeri Varış Tarih Saat for {key}")
      if 'Olay Yeri Varış Tarihi' in dataframe[key].columns and 'Olay Yeri Varış Saati' in dataframe[key].columns:
        dataframe[key]['Olay Yeri Varış Saati'] = dataframe[key]['Olay Yeri Varış Saati']
        dataframe[key]["Olay Yeri Varış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Olay Yeri Varış Tarihi'] + ' ' + dataframe[key]['Olay Yeri Varış Saati'],
            format='mixed'
        )
      else:
          print(f"Warning: 'Olay Yeri Varış Tarihi' or 'Olay Yeri Varış Saati' not found in {key}. Cannot create 'Olay Yeri Varış Tarih Saat'.")
    else:
        print(f"Converting Olay Yeri Varış Tarih Saat to datetime for {key}")
        dataframe[key]['Olay Yeri Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Varış Tarih Saat'], format='mixed')

    # Process 'Olay Yeri Ayrılış Tarih Saat'
    if 'Olay Yeri Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Olay Yeri Ayrılış Tarih Saat for {key}")
      if 'Olay Yeri Ayrılış Tarihi' in dataframe[key].columns and 'Olay Yeri Ayrılış Saati' in dataframe[key].columns:
        dataframe[key]['Olay Yeri Ayrılış Saati'] = dataframe[key]['Olay Yeri Ayrılış Saati']
        dataframe[key]["Olay Yeri Ayrılış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Olay Yeri Ayrılış Tarihi'] + ' ' + dataframe[key]['Olay Yeri Ayrılış Saati'],
            format='mixed'
        )
      else:
          print(f"Warning: 'Olay Yeri Ayrılış Tarihi' or 'Olay Yeri Ayrılış Saati' not found in {key}. Cannot create 'Olay Yeri Ayrılış Tarih Saat'.")
    else:
        print(f"Converting Olay Yeri Ayrılış Tarih Saat to datetime for {key}")
        dataframe[key]['Olay Yeri Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Ayrılış Tarih Saat'], format= 'mixed')

    # Process 'Hastaneye Varış Tarih Saat'
    # Note the inconsistent column name 'Hastaneye varış Tarih Saat' found in the traceback
    if 'Hastaneye Varış Tarih Saat' not in dataframe[key].columns and 'Hastaneye varış Tarih Saat' in dataframe[key].columns:
         dataframe[key].rename(columns={'Hastaneye varış Tarih Saat':'Hastaneye Varış Tarih Saat'}, inplace=True)

    if 'Hastaneye Varış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Hastaneye Varış Tarih Saat for {key}")
      if 'Hastaneye Varış Tarihi' in dataframe[key].columns and 'Hastaneye Varış Saati' in dataframe[key].columns:
        dataframe[key]['Hastaneye Varış Saati'] = dataframe[key]['Hastaneye Varış Saati']
        dataframe[key]["Hastaneye Varış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Hastaneye Varış Tarihi'] + ' ' + dataframe[key]['Hastaneye Varış Saati'],
            format='mixed'
        )
      else:
          print(f"Warning: 'Hastaneye Varış Tarihi' or 'Hastaneye Varış Saati' not found in {key}. Cannot create 'Hastaneye Varış Tarih Saat'.")
    else:
        print(f"Converting Hastaneye Varış Tarih Saat to datetime for {key}")
        dataframe[key]['Hastaneye Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneye Varış Tarih Saat'], format='mixed')

    # Process 'Hastaneden Ayrılış Tarih Saat'
    if 'Hastaneden Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Creating Hastaneden Ayrılış Tarih Saat for {key}")
      if 'Hastaneden Ayrılış Tarihi' in dataframe[key].columns and 'Hastaneden Ayrılış Saati' in dataframe[key].columns:
        dataframe[key]['Hastaneden Ayrılış Saati'] = dataframe[key]['Hastaneden Ayrılış Saati']
        dataframe[key]["Hastaneden Ayrılış Tarih Saat"] = pd.to_datetime(
            dataframe[key]['Hastaneden Ayrılış Tarihi'] + ' ' + dataframe[key]['Hastaneden Ayrılış Saati'],
            format='mixed'
        )
      else:
          print(f"Warning: 'Hastaneden Ayrılış Tarihi' or 'Hastaneden Ayrılış Saati' not found in {key}. Cannot create 'Hastaneden Ayrılış Tarih Saat'.")
    else:
        print(f"Converting Hastaneden Ayrılış Tarih Saat to datetime for {key}")
        dataframe[key]['Hastaneden Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneden Ayrılış Tarih Saat'], format='mixed')

# %%
for key in dataframes_2024_2025.keys():
  print(f"{key} is proccessing")
  dataframes_2024_2025[key]['İhbar/Çağrı Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['İhbar/Çağrı Tarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['İhbar/Çağrı  Saati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')
  dataframes_2024_2025[key]['Vaka Veriliş Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['Vaka Veriliş\nTarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['Vaka Veriliş\nSaati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')
  dataframes_2024_2025[key]['Olay Yeri Varış Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['Olay Yeri Varış Tarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['Olay Yeri Varış Saati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')
  dataframes_2024_2025[key]['Olay Yeri Ayrılış Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['Olay Yeri Ayrılış Tarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['Olay Yeri Ayrılış Saati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')
  dataframes_2024_2025[key]['Hastaneye Varış Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['Hastaneye Varış Tarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['Hastaneye Varış Saati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')
  dataframes_2024_2025[key]['Hastaneden Ayrılış Tarih Saat']= pd.to_datetime(dataframes_2024_2025[key]['Hastaneden Ayrılış Tarihi'].astype(str).str.strip() + ' ' + dataframes_2024_2025[key]['Hastaneden Ayrılış Saati'].astype(str).str.strip(), format= 'mixed', errors= 'coerce')

# %%
dataframes_2018_2019['2018 YILI AVRUPA'].iloc[388904]['Vaka Veriliş Tarih Saat']

# %%
data_2022_2024= [dataframes_2022_2023, dataframes_2024_2025]

# %%
dataframes_2022_2023["2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ"]["İhbar/Çağrı Tarihi"].isna().sum()

# %%
"""for dataframe in data_2022_2024:
  for key in dataframe.keys():
    if "Hastaneye Varış Saati\n" in dataframe[key].columns:
      dataframe[key].rename(columns={"Hastaneye Varış Saati\n": "Hastaneye Varış Saati"}, inplace=True)
    if "İhbar/Çağrı Tarih Saat" not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} İhbar/Çağrı Tarih Saat")
      dataframe[key]['İhbar/Çağrı Tarihi']= dataframe[key]['İhbar/Çağrı Tarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["İhbar/Çağrı Tarih Saat"]= pd.to_datetime(dataframe[key]['İhbar/Çağrı Tarihi'] + ' ' + dataframe[key]['İhbar/Çağrı  Saati'], format= 'mixed', errors= 'coerce')
    if "Vaka Veriliş Tarih Saat" not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} Vaka Veriliş Tarih Saat")
      dataframe[key]['Vaka Veriliş\nTarihi'] = dataframe[key]['Vaka Veriliş\nTarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["Vaka Veriliş Tarih Saat"]= pd.to_datetime(dataframe[key]['Vaka Veriliş\nTarihi'] + ' ' + dataframe[key]['Vaka Veriliş\nSaati'], format= 'mixed', errors= 'coerce')
    if "Olay Yeri Varış Tarih Saat" not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} Olay Yeri Varış Tarih Saat")
      dataframe[key]['Olay Yeri Varış Tarihi']= dataframe[key]['Olay Yeri Varış Tarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["Olay Yeri Varış Tarih Saat"]= pd.to_datetime(dataframe[key]['Olay Yeri Varış Tarihi'] + ' ' + dataframe[key]['Olay Yeri Varış Saati'], format= 'mixed', errors= 'coerce')
    if 'Olay Yeri Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} Olay Yeri Ayrılış Tarih Saat")
      dataframe[key]['Olay Yeri Ayrılış Tarihi']= dataframe[key]['Olay Yeri Ayrılış Tarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["Olay Yeri Ayrılış Tarih Saat"]= pd.to_datetime(dataframe[key]['Olay Yeri Ayrılış Tarihi'] + ' ' + dataframe[key]['Olay Yeri Ayrılış Saati'], format= 'mixed', errors= 'coerce')
    if 'Hastaneye Varış Tarih Saat' not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} Hastaneye Varış Tarih Saat")
      dataframe[key]['Hastaneye Varış Tarihi']= dataframe[key]['Hastaneye Varış Tarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["Hastaneye varış Tarih Saat"]= pd.to_datetime(dataframe[key]['Hastaneye Varış Tarihi'] + ' ' + dataframe[key]['Hastaneye Varış Saati'], format= 'mixed', errors= 'coerce')
    if 'Hastaneden Ayrılış Tarih Saat' not in dataframe[key].columns:
      print(f"Starting to process\n|\n|\n| {key} Hastaneden Ayrılış Tarih Saat")
      dataframe[key]['Hastaneden Ayrılış Tarihi']= dataframe[key]['Hastaneden Ayrılış Tarihi'].apply(lambda x: x.split(' ')[0] if isinstance(x, str) else pd.NaT)
      dataframe[key]["Hastaneden Ayrılış Tarih Saat"]= pd.to_datetime(dataframe[key]['Hastaneden Ayrılış Tarihi'] + ' ' + dataframe[key]['Hastaneden Ayrılış Saati'], format= 'mixed', errors= 'coerce')"""

# %%
"""temp_df= pd.read_excel(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\2022\total\2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ.xlsx")"""

# %%
"""temp_df["İhbar/Çağrı Tarihi"].value_counts()"""

# %%
all_datas= [dataframes_2018_2019, dataframes_2020_2021, dataframes_2022_2023, dataframes_2024_2025]

# %%
for dataframes in all_datas:
    for key in dataframes.keys():
        if 'İhbar/Çağrı Tarihi' in dataframes[key].columns:
            print(f"Processing {key}")
            print(dataframes[key]["İhbar/Çağrı Tarih Saat"].isna().sum(),'---->', dataframes[key]['İhbar/Çağrı Tarihi'].isna().sum(), "-------NaN values")

# %%
dataframes_2022_2023["2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ"][dataframes_2022_2023["2022  AVRUPA OCAK-ARALIK DEFTER BİRLEŞMİŞ"]["İhbar/Çağrı Tarih Saat"].isna()][["İhbar/Çağrı Tarihi","İhbar/Çağrı Tarih Saat"]]

# %%
"""for dataframe in all_datas:
    for key in dataframe.keys():
        print(f"Processing {key}")
        if "Hastaneye Varış Saati\n" in dataframe[key].columns:
            dataframe[key].rename(columns={"Hastaneye Varış Saati\n": "Hastaneye Varış Saati"}, inplace=True)
        if "İhbar/Çağrı Tarih Saat" in dataframe[key].columns:
            dataframe[key]['İhbar/Çağrı Tarih Saat'] = pd.to_datetime(dataframe[key]['İhbar/Çağrı Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['İhbar/Çağrı Tarih Saat'] = pd.to_datetime(dataframe[key]['İhbar/Çağrı Tarihi'] + ' ' + dataframe[key]["İhbar/Çağrı  Saati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        if "Vaka Veriliş Tarih Saat" in dataframe[key].columns:
            dataframe[key]['Vaka Veriliş Tarih Saat'] = pd.to_datetime(dataframe[key]['Vaka Veriliş Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['Vaka Veriliş Tarih Saat'] = pd.to_datetime(dataframe[key]['Vaka Veriliş\nTarihi'] + ' ' + dataframe[key]["Vaka Veriliş\nSaati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        if "Olay Yeri Varış Tarih Saat" in dataframe[key].columns:
            dataframe[key]['Olay Yeri Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Varış Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['Olay Yeri Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Varış Tarihi'] + ' ' + dataframe[key]["Olay Yeri Varış Saati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        if "Olay Yeri Ayrılış Tarih Saat" in dataframe[key].columns:
            dataframe[key]['Olay Yeri Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Ayrılış Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['Olay Yeri Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Olay Yeri Ayrılış Tarihi'] + ' ' + dataframe[key]["Olay Yeri Ayrılış Saati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        if "Hastaneye Varış Tarih Saat" in dataframe[key].columns:
            dataframe[key]['Hastaneye Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneye Varış Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['Hastaneye Varış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneye Varış Tarihi'] + ' ' + dataframe[key]["Hastaneye Varış Saati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        if "Hastaneden Ayrılış Tarih Saat" in dataframe[key].columns:
            dataframe[key]['Hastaneden Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneden Ayrılış Tarih Saat'], format='%d-%m-%Y %H:%M:%S', errors='coerce')
        else:
            dataframe[key]['Hastaneden Ayrılış Tarih Saat'] = pd.to_datetime(dataframe[key]['Hastaneden Ayrılış Tarihi'] + ' ' + dataframe[key]["Hastaneden Ayrılış Saati"], format='%d-%m-%Y %H:%M:%S', errors='coerce')"""

# %%
for dataframe in all_datas:
  for key in dataframe.keys():
    for col in dataframe[key]:
      if "Olay Yeri Ayrılış" == col:
        print(key)
      else:
        print('not found')
        #dataframe[key].rename(columns={'Olay Yeri Ayrılış':'Olay Yeri Ayrılış Tarih Saat'}, inplace=True)

# %%
necessary_columns

# %%
dataframes_2022_2023[]

# %%
dataframes_2020_2021['2020 YILI OCAK-HAZİRAN AYLARI DEFTER']['Dönüş KM']

# %%
all_datas= [dataframes_2018_2019,dataframes_2020_2021, dataframes_2022_2023, dataframes_2024_2025].copy()

# %%
dataframes_2024_2025['1-OCAK 2025 AVR ASOS TANI DÖNÜŞTÜRÜLMÜŞ DEFTER']['Hastaneye Varış Km']

# %%
for dataframes in all_datas:
  for dataframe in dataframes.keys():
    dataframes[dataframe].rename(columns={'Varış Km':'Varış KM', 'Hastaneye Varış Km':'Hastaneye Varış KM'}, inplace=True)

# %%
for dataframe in all_datas:
  for key in dataframe.keys():
      for necessary_column in necessary_columns:
        if necessary_column not in dataframe[key].columns:
            print(f"{necessary_column} not found in {key}")

# %%
save_path_0= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2017\\"
save_path_001= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2018_2019\\"
save_path_1= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2020_2021\\"
save_path_2= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2022_2023\\"
save_path_3= r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\2024_2025\\"

# %%
for key in dataframes_2017.keys():
  print(f"saving {key}")
  dataframes_2017[key].to_parquet(save_path_0 + key + ".parquet")
for key in dataframes_2018_2019.keys():
  print(f"saving {key}")
  dataframes_2018_2019[key].to_parquet(save_path_001 + key + ".parquet")
for key in dataframes_2020_2021.keys():
  print(f"saving {key}")
  dataframes_2020_2021[key].to_parquet(save_path_1 + key + ".parquet")
for key in dataframes_2022_2023.keys():
  dataframes_2022_2023[key].to_parquet(save_path_2 + key + ".parquet")
  print(f"saving {key}")
for key in dataframes_2024_2025.keys():
  print(f"saving {key}")
  dataframes_2024_2025[key].to_parquet(save_path_3 + key + ".parquet")

# %%
all_datas= [dataframes_2018_2019,dataframes_2020_2021, dataframes_2022_2023, dataframes_2024_2025]

# %%
dataframes_2020_2021['2021 YILI OCAK-HAZİRAN ASOS DEFTER AVRUPA']

# %%
for dataframes in all_datas:
  for dataframe in dataframes.keys():
    print(dataframe)
    print([col for col in necessary_columns if col not in dataframes[dataframe].columns], "\n")
    columns_to_add= [col for col in necessary_columns if col not in dataframes[dataframe].columns]
    for col in columns_to_add:
      dataframes[dataframe][col]= pd.NA

# %%
for dataframes in all_datas:
  for dataframe in dataframes.keys():
    print(dataframe)
    print([col for col in necessary_columns if col not in dataframes[dataframe].columns], "\n")

# %%
dataframes_2018_2019['2019 YILI ASOS AVR']['Sonuç'].value_counts()

# %%
dataframes_2024_2025['2-ŞUBAT 2025 AVR ASOS TANI DÖNÜŞTÜRÜLMÜŞ DEFTER']['Sonuç'].value_counts()

# %%
dataframes_2024_2025['2024 OCAK-HAZİRAN AVR 6 AYLIK TANI DÖNÜŞTÜRÜLMÜŞ ASOS DEFTER']['Sonuç'].value_counts()

# %%
necessary_columns

# %%
dataframes_2018_2019['2018 YILI AVRUPA'][['İhbar Adresi']].to_csv('test.csv')

# %%
df= pd.DataFrame()

# %%
all_datas= [dataframes_2018_2019, dataframes_2020_2021, dataframes_2022_2023, dataframes_2024_2025]

# %%
for dataframes in all_datas:
  for dataframe in dataframes.keys():
    df= pd.concat([df, dataframes[dataframe][necessary_columns]])

# %%
dataframes_2018_2019['2018 YILI AVRUPA']['İhbar/Çağrı Tarih Saat'].isna().sum()

# %%
len(dataframes_2018_2019['2018 YILI AVRUPA'])

# %%
empty_values

# %%
df.to_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file.parquet")

# %%
df.info()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import duckdb

import datetime as dt
import os
from concurrent.futures import ThreadPoolExecutor

# %%
con = duckdb.connect()
con.execute("INSTALL excel")
con.execute("LOAD excel")

# %%
df= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file.parquet")

# %%
df
# Out:
#       KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan  \
# 0           524105    ZTB3    2018-08-12 21:08:46        -          -
# 1           516229    ZTB2    2018-03-12 17:18:46        -          -
# 2           556760    KÇK8    2018-12-29 20:28:02        -          -
# 3           539730    KÇK6    2018-12-19 00:05:44        -          -
# 4           539892    KÇK2    2018-12-19 04:25:54        -          -
# ...            ...     ...                    ...      ...        ...
# 56915    115057184    EYP3    2025-04-30 03:18:03    ERKEK          -
# 56916    115061653    BÇK3    2025-04-30 03:35:57    ERKEK          -
# 56917    115061653    BÇK7    2025-04-30 03:35:57    KADIN          -
# 56918    115109148    ESN6    2025-04-30 21:51:59        -          -
# 56919    115102844    BAG9    2025-04-30 19:31:08    ERKEK          -
#
#               Yaş  Adli Vaka   Çağrı Nedeni               Sonuç  \
# ...

# %%
df.columns
# Out:
# Index(['KKM Protokol', 'Ekip No', 'İhbar/Çağrı Tarih Saat', 'Cinsiyet',
#        'Yeni Doğan', 'Yaş', 'Adli Vaka', 'Çağrı Nedeni', 'Sonuç',
#        'Nakledilen Hastane', 'ICD10 TANI\nADI', 'Triaj', 'Bilinç', 'Nabız',
#        'Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat',
#        'Olay Yeri Ayrılış Tarih Saat', 'Hastaneye Varış Tarih Saat',
#        'Hastaneden Ayrılış Tarih Saat', 'Müdahale Süresi Sn',
#        'Hastane Teslim Süresi Sn', 'Çıkış KM', 'Varış KM',
#        'Hastaneye Varış KM', 'Dönüş KM', 'Vakanın Enlemi', 'Vakanın Boylamı',
#        'Tansiyon', 'Glukoz', 'Ateş', 'SPO2', 'Solunum Değeri', 'Nabız Değeri'],
#       dtype='object')

# %%
# ANOTHER WAY TO FIND BY LAT AND LON
import json

import geopandas as gpd
from shapely.geometry import Point
import pandas as pd # Import pandas

def print_lonLat_columns(df):
    """Prints columns containing the substring 'enlem' (case-insensitive)."""

    for col in df.columns:
        if ('enlem' in col.lower()) | ('boylam' in col.lower()) | (col.lower() == 'lat') | (col.lower() == 'lon'):
            print(col)


def get_district_neighbourhood(df):
  # Load districts
  with open("C:/Users/mkaya/Onedrive/Masaüstü/istanbul112_hidden/data/locations/istanbul-districts.json", "r", encoding="utf-8") as f:
      districts_data = json.load(f)
      districts_gdf = gpd.GeoDataFrame.from_features(districts_data["features"])
  print_lonLat_columns(df)
  lat = "Vakanın Enlemi" if "Vakanın Enlemi" in df.columns else str(input('latitude column: '))
  lon = "Vakanın Boylamı" if "Vakanın Boylamı" in df.columns else str(input('longitude column: '))
  
  columns= [col for col in df.columns] + ['Neighbourhood', 'District']
  # Load neighborhoods
  neighbourhoods_gdf = gpd.read_file("C:/Users/mkaya/Onedrive/Masaüstü/istanbul112_hidden/data/locations/istanbul_neighbourhoods.geojson")

  # Convert latitude and longitude columns to numeric, coercing errors to NaN
  df[lat] = pd.to_numeric(df[lat], errors='coerce')
  df[lon] = pd.to_numeric(df[lon], errors='coerce')
  df_cleaned = df
  # Convert Vakanın Enlemi and Vakanın Boylamı to geometry points
  df_cleaned["geometry"] = df_cleaned.apply(lambda row: Point(row[lon], row[lat]), axis=1)
  points_gdf = gpd.GeoDataFrame(df_cleaned, geometry="geometry", crs="EPSG:4326")

  # Spatial join to find districts
  points_gdf = gpd.sjoin(points_gdf, districts_gdf, how="left", predicate="within")
  points_gdf.rename(columns={"name": "District"}, inplace=True)

  # Drop 'index_right' before the second spatial join
  if 'index_right' in points_gdf.columns:
      points_gdf = points_gdf.drop(columns=['index_right'])

  # Spatial join to find neighborhoods
  points_gdf = gpd.sjoin(points_gdf, neighbourhoods_gdf, how="left", predicate="within")
  points_gdf.rename(columns={"name": "Neighbourhood"}, inplace=True)

  # Select relevant columns and return
  return points_gdf[columns]

df= get_district_neighbourhood(df)
# Out:
# Vakanın Enlemi
# Vakanın Boylamı
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_21660\3803927538.py:38: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: None
#
#   points_gdf = gpd.sjoin(points_gdf, districts_gdf, how="left", predicate="within")

# %%
df.to_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_with_neighbourhood.parquet")

# %%
df= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_with_neighbourhood.parquet")

# %%
len(df)
# Out:
# 4276743

# %%
df
# Out:
#       KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan  \
# 0           524105    ZTB3    2018-08-12 21:08:46        -          -
# 1           516229    ZTB2    2018-03-12 17:18:46        -          -
# 2           556760    KÇK8    2018-12-29 20:28:02        -          -
# 3           539730    KÇK6    2018-12-19 00:05:44        -          -
# 4           539892    KÇK2    2018-12-19 04:25:54        -          -
# ...            ...     ...                    ...      ...        ...
# 56915    115057184    EYP3    2025-04-30 03:18:03    ERKEK          -
# 56916    115061653    BÇK3    2025-04-30 03:35:57    ERKEK          -
# 56917    115061653    BÇK7    2025-04-30 03:35:57    KADIN          -
# 56918    115109148    ESN6    2025-04-30 21:51:59        -          -
# 56919    115102844    BAG9    2025-04-30 19:31:08    ERKEK          -
#
#               Yaş  Adli Vaka   Çağrı Nedeni               Sonuç  \
# ...

# %%
istanbul_population_density= pd.read_csv(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\populations\istanbul_population_density.csv")

# %%
istanbul_population_density['Ilce']= istanbul_population_density['Ilce'].str.strip()

# %%
df['District']= df['District'].str.strip()

# %%
istanbul_population_density= istanbul_population_density[['Ilce', 'Nüfus']]

# %%
istanbul_population_density.rename(columns={'Nüfus':'District Population Density', 'Ilce':'District'}, inplace=True)
# Out:
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_21660\281424629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   istanbul_population_density.rename(columns={'Nüfus':'District Population Density', 'Ilce':'District'}, inplace=True)

# %%
istanbul_population_density_dict= istanbul_population_density.set_index('District').to_dict()['District Population Density']

# %%
df['District Population Density']= df['District'].map(istanbul_population_density_dict)

# %%
df
# Out:
#       KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan  \
# 0           524105    ZTB3    2018-08-12 21:08:46        -          -
# 1           516229    ZTB2    2018-03-12 17:18:46        -          -
# 2           556760    KÇK8    2018-12-29 20:28:02        -          -
# 3           539730    KÇK6    2018-12-19 00:05:44        -          -
# 4           539892    KÇK2    2018-12-19 04:25:54        -          -
# ...            ...     ...                    ...      ...        ...
# 56915    115057184    EYP3    2025-04-30 03:18:03    ERKEK          -
# 56916    115061653    BÇK3    2025-04-30 03:35:57    ERKEK          -
# 56917    115061653    BÇK7    2025-04-30 03:35:57    KADIN          -
# 56918    115109148    ESN6    2025-04-30 21:51:59        -          -
# 56919    115102844    BAG9    2025-04-30 19:31:08    ERKEK          -
#
#               Yaş  Adli Vaka   Çağrı Nedeni               Sonuç  \
# ...

# %%
df.head()
# Out:
#   KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan Yaş  \
# 0       524105    ZTB3    2018-08-12 21:08:46        -          -   0
# 1       516229    ZTB2    2018-03-12 17:18:46        -          -   0
# 2       556760    KÇK8    2018-12-29 20:28:02        -          -   0
# 3       539730    KÇK6    2018-12-19 00:05:44        -          -   0
# 4       539892    KÇK2    2018-12-19 04:25:54        -          -   0
#
#   Adli Vaka Çağrı Nedeni  Sonuç Nakledilen Hastane  ... Vakanın Boylamı  \
# 0         -      Medikal  Diğer                  -  ...             NaN
# 1         -      Medikal  Diğer                  -  ...             NaN
# 2         -      Medikal  Diğer                  -  ...             NaN
# 3         -      Medikal  Diğer                  -  ...             NaN
# 4         -      Medikal  Diğer                  -  ...             NaN
#
#   Tansiyon Glukoz  Ateş  SPO2 Solunum Değeri Nabız Değeri Neighbourhood  \
# ...

# %%
df.to_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_3_with_neighbourhood_and_population_density.parquet")

# %%
df['case_response_time'] = round((pd.to_datetime(df['Olay Yeri Varış Tarih Saat']) - pd.to_datetime(df['İhbar/Çağrı Tarih Saat'])).dt.total_seconds() / 60, 2)  # Convert to minutes

# %%
df.head()
# Out:
#   KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan Yaş  \
# 0       524105    ZTB3    2018-08-12 21:08:46        -          -   0
# 1       516229    ZTB2    2018-03-12 17:18:46        -          -   0
# 2       556760    KÇK8    2018-12-29 20:28:02        -          -   0
# 3       539730    KÇK6    2018-12-19 00:05:44        -          -   0
# 4       539892    KÇK2    2018-12-19 04:25:54        -          -   0
#
#   Adli Vaka Çağrı Nedeni  Sonuç Nakledilen Hastane  ... Tansiyon Glukoz  Ateş  \
# 0         -      Medikal  Diğer                  -  ...     None   None  None
# 1         -      Medikal  Diğer                  -  ...     None   None  None
# 2         -      Medikal  Diğer                  -  ...     None   None  None
# 3         -      Medikal  Diğer                  -  ...     None   None  None
# 4         -      Medikal  Diğer                  -  ...     None   None  None
#
#    SPO2 Solunum Değeri Nabız Değeri Neighbourhood District  \
# ...

# %%
df['Çıkış KM'].fillna(np.nan, inplace=True)
df['Varış KM'].fillna(np.nan, inplace=True)
# Out:
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_21660\3405500442.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Çıkış KM'].fillna(np.nan, inplace=True)
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_21660\3405500442.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['total_distance'] = df["Dönüş KM"].astype(float) - df['Çıkış KM'].astype(float)

# %%
df[['Dönüş KM', 'Çıkış KM', 'total_distance']].head()
# Out:
#   Dönüş KM Çıkış KM  total_distance
# 0   350792   350786             6.0
# 1   208875   208869             6.0
# 2   400649   400648             1.0
# 3   241471   241461            10.0
# 4   213045   213039             6.0

# %%
df.head()
# Out:
#   KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan Yaş  \
# 0       524105    ZTB3    2018-08-12 21:08:46        -          -   0
# 1       516229    ZTB2    2018-03-12 17:18:46        -          -   0
# 2       556760    KÇK8    2018-12-29 20:28:02        -          -   0
# 3       539730    KÇK6    2018-12-19 00:05:44        -          -   0
# 4       539892    KÇK2    2018-12-19 04:25:54        -          -   0
#
#   Adli Vaka Çağrı Nedeni  Sonuç Nakledilen Hastane  ... Glukoz  Ateş  SPO2  \
# 0         -      Medikal  Diğer                  -  ...   None  None  None
# 1         -      Medikal  Diğer                  -  ...   None  None  None
# 2         -      Medikal  Diğer                  -  ...   None  None  None
# 3         -      Medikal  Diğer                  -  ...   None  None  None
# 4         -      Medikal  Diğer                  -  ...   None  None  None
#
#   Solunum Değeri Nabız Değeri Neighbourhood District  \
# ...

# %%
len(df)
# Out:
# 4276743

# %%
df.to_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_4_with_neighbourhood_and_population_density.parquet")

# %%
df= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_4_with_neighbourhood_and_population_density.parquet")

# %%
df['Cinsiyet'].unique()
# Out:
# array(['-', 'ERKEK', 'KADIN', "HBYS'den Cinsiyet Verisi Gelmedi",
#        'HBYS den Cinsiyet Verisi Gelmedi'], dtype=object)

# %%
df['Yaş']= df['Yaş'].str.replace('-', '')

# %%
df['Nabız Değeri'].unique()
# Out:
# array([None, '100', '88', '105', '86', '90', '91', '110', '96', '87', '-',
#        '00', '80', '123', '77', '76', '85', '84', '121', '103', '107',
#        '135', '127', '78', '68', '89', '141', '95', '145', '83', '81',
#        '94', '125', '40', '0', '70', '79', '71', '75', '165', '138',
#        '106', '134', '82', '120', '104', '130', '102', '140', '92', '72',
#        '66', '73', '108', '74', '112', '93', '97', '101', '65', '98',
#        '99', '126', '62', '160', '55', '170', '60', '53', '69', '147',
#        '122', '47', '111', '16', '115', '124', '114', '34', '150', '118',
#        '67', '158', '149', '146', '128', '54', '116', '144', '113', '136',
#        '154', '155', '180', '21', '131', '52', '270', '132', '133', '117',
#        '64', '161', '56', '57', '162', '225', '109', '10', '50', '129',
#        '143', '51', '61', '142', '119', '148', '153', '173', '151', '199',
#        '168', '230', '20', '14', '45', '63', '42', '190', '39', '260',
# ...

# %%
print(df.columns)
# Out:
# Index(['KKM Protokol', 'Ekip No', 'İhbar/Çağrı Tarih Saat', 'Cinsiyet',
#        'Yeni Doğan', 'Yaş', 'Adli Vaka', 'Çağrı Nedeni', 'Sonuç',
#        'Nakledilen Hastane', 'ICD10 TANI\nADI', 'Triaj', 'Bilinç', 'Nabız',
#        'Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat',
#        'Olay Yeri Ayrılış Tarih Saat', 'Hastaneye Varış Tarih Saat',
#        'Hastaneden Ayrılış Tarih Saat', 'Müdahale Süresi Sn',
#        'Hastane Teslim Süresi Sn', 'Çıkış KM', 'Varış KM',
#        'Hastaneye Varış KM', 'Dönüş KM', 'Vakanın Enlemi', 'Vakanın Boylamı',
#        'Tansiyon', 'Glukoz', 'Ateş', 'SPO2', 'Solunum Değeri', 'Nabız Değeri',
#        'Neighbourhood', 'District', 'District Population Density',
#        'case_response_time', 'total_distance'],
#       dtype='object')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\mkaya\\OneDrive\\Belgeler\\GitHub\\istanbul_analysis\\ipynb_workouts'

# %%
df['Ateş'].value_counts()
# Out:
# Ateş
# -        2087269
# 36         54918
# 36.5       31992
# 37         21104
# 36.4       16129
#           ...
# 37.89          1
# 97.7           1
# 98.2           1
# 17.1           1
# 96.9           1
# Name: count, Length: 405, dtype: int64

# %%
df['Ateş']= df['Ateş'].apply(lambda x: float(x) if isinstance(x, str) and x.replace('.', '', 1).isdigit() else np.nan)
df['Yaş']= df['Yaş'].apply(lambda x: int(x) if isinstance(x, str) and x.isdigit() else np.nan)
df['Nabız Değeri']= df['Nabız Değeri'].apply(lambda x: float(x) if isinstance(x, str) and x.replace('.', '', 1).isdigit() else np.nan)
df['Glukoz']= df['Glukoz'].apply(lambda x: float(x) if isinstance(x, str) and x.replace('.', '', 1).isdigit() else np.nan)
df['SPO2']= df['SPO2'].apply(lambda x: float(x) if isinstance(x, str) and x.replace('.', '', 1).isdigit() else np.nan)
df['Solunum Değeri']= df['Solunum Değeri'].apply(lambda x: float(x) if isinstance(x, str) and x.replace('.', '', 1).isdigit() else np.nan)

# %%
df.loc[(df['total_distance']>1000) | (df['total_distance']<0), 'total_distance']= np.nan
df.loc[(df['case_response_time']>1440) | (df['case_response_time']<0), 'case_response_time']= np.nan
df.loc[(df['Ateş'] > 50) | (df['Ateş'] < 0), 'Ateş'] = np.nan
df.loc[(df['Yaş'] > 120) | (df['Yaş'] < 0), 'Yaş'] = np.nan
df.loc[(df['Nabız Değeri'] > 300) | (df['Nabız Değeri'] < 0), 'Nabız Değeri'] = np.nan
df.loc[(df['Glukoz'] > 1000) | (df['Glukoz'] < 0), 'Glukoz'] = np.nan
df.loc[(df['SPO2'] > 100) | (df['SPO2'] < 0), 'SPO2'] = np.nan
df.loc[(df['Solunum Değeri'] > 100) | (df['Solunum Değeri'] < 0), 'Solunum Değeri'] = np.nan
df['Ateş'].fillna(np.nan, inplace=True)
df['Yaş'].fillna(np.nan, inplace=True)  
df['Nabız Değeri'].fillna(np.nan, inplace=True)
df['Glukoz'].fillna(np.nan, inplace=True)
df['SPO2'].fillna(np.nan, inplace=True)
df['Solunum Değeri'].fillna(np.nan, inplace=True)
# Out:
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_17368\1732036469.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ateş'].fillna(np.nan, inplace=True)
# C:\Users\mkaya\AppData\Local\Temp\ipykernel_17368\1732036469.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
icd_scores= pd.read_csv("icd10_diagnoses_scored.csv")

# %%
icd_scores['ICD10 TANI']= icd_scores['ICD10 TANI'].str.strip()
icd_scores_dict= icd_scores.set_index('ICD10 TANI').to_dict()['Expanded Score']

# %%
df['icd_score'] = df['ICD10 TANI\nADI'].map(icd_scores_dict)

# %%
df
# Out:
#       KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan   Yaş  \
# 0           524105    ZTB3    2018-08-12 21:08:46        -          -   0.0
# 1           516229    ZTB2    2018-03-12 17:18:46        -          -   0.0
# 2           556760    KÇK8    2018-12-29 20:28:02        -          -   0.0
# 3           539730    KÇK6    2018-12-19 00:05:44        -          -   0.0
# 4           539892    KÇK2    2018-12-19 04:25:54        -          -   0.0
# ...            ...     ...                    ...      ...        ...   ...
# 56915    115057184    EYP3    2025-04-30 03:18:03    ERKEK          -  37.0
# 56916    115061653    BÇK3    2025-04-30 03:35:57    ERKEK          -  19.0
# 56917    115061653    BÇK7    2025-04-30 03:35:57    KADIN          -  20.0
# 56918    115109148    ESN6    2025-04-30 21:51:59        -          -   NaN
# 56919    115102844    BAG9    2025-04-30 19:31:08    ERKEK          -  46.0
#
#        Adli Vaka   Çağrı Nedeni               Sonuç  \
# ...

# %%
# Scoring functions
def age_score(age):
    try:
        age = int(age)
        if age < 0:
            return 1
        elif age <= 18:
            return 2
        elif 18 < age <= 65:
            return 3
        elif age > 65:
            return 4
    except:
        return 1

def cagri_score(val):
    high_impact = ["Terör", "Trafik Kazası", "Yaralama", "Beyaz Kod Sağlık Personeline Şiddet"]
    med_impact = ["Medikal", "Diğer Kazalar", "İntihar"]
    if val in high_impact:
        return 4
    elif val in med_impact:
        return 3
    else:
        return 1

def sonuc_score(val):
    high_impact = [
        "Nakil - Hastaneye", "Ex - Yerinde Bırakıldı", "Nakil - Eve",
        "Nakil - Tıbbi Tetkik İçin", "Nakil - Hastaneler Arası", "Ex - Morga Nakil"
    ]
    med_impact = ["Diğer", "Olay Yerinde Bekleme", "Yerinde Müdahale", "Nakil - Diğer"]
    if val in high_impact:
        return 4
    elif val in med_impact:
        return 3
    else:
        return 1

def tansiyon_score(val):
    try:
        s, d = map(int, str(val).split("/"))
        score = 1
        if s < 80 or s > 180 or d < 50 or d > 110:
            score = 4
        elif (80 <= s < 90 or 140 < s <= 180) or (50 <= d < 60 or 90 < d <= 110):
            score = 3
        elif (90 <= s < 100 or 130 < s <= 140) or (60 <= d < 70 or 80 < d <= 90):
            score = 2
        return score
    except:
        return 1

def glukoz_score(val):
    try:
        g = float(val)
        if g < 40 or g > 400:
            return 4
        elif 40 <= g < 60 or 200 < g <= 400:
            return 3
        elif 60 <= g < 70 or 140 < g <= 200:
            return 2
        else:
            return 1
    except:
        return 1

def ates_score(val):
    try:
        t = float(val)
        if t < 30 or t > 41:
            return 4
        elif 30 <= t < 34 or 39 < t <= 41:
            return 3
        elif 34 <= t < 36 or 38 < t <= 39:
            return 2
        else:
            return 1
    except:
        return 1

def spo2_score(val):
    try:
        s = float(val)
        if s < 70:
            return 4
        elif 70 <= s < 85:
            return 3
        elif 85 <= s < 94:
            return 2
        else:  # 94-100
            return 1
    except:
        return 1

def solunum_score(val):
    try:
        v = float(val)
        if v < 5 or v > 40:
            return 4
        elif 5 <= v < 10 or 30 < v <= 40:
            return 3
        elif 10 <= v < 12 or 24 < v <= 30:
            return 2
        else:  # 12-24
            return 1
    except:
        return 1

def nabiz_deg_score(val):
    try:
        v = float(val)
        if v < 40 or v > 150:
            return 4
        elif 40 <= v < 50 or 130 < v <= 150:
            return 3
        elif 50 <= v < 60 or 120 < v <= 130:
            return 2
        else:  # 60-120 normal
            return 1
    except:
        return 1

# Apply all scores
df["cinsiyet_score"] = df["Cinsiyet"].map({
    "ERKEK": 3,
    "KADIN": 2
}).fillna(1)

df["yeni_dogan_score"] = df["Yeni Doğan"].apply(lambda x: 3 if x == "Yeni Doğan" else 1)
df["yas_score"] = df["Yaş"].apply(age_score)
df["adli_vaka_score"] = df["Adli Vaka"].apply(lambda x: 3 if x == "Adli Vaka" else 1)
df["cagri_nedeni_score"] = df["Çağrı Nedeni"].apply(cagri_score)
df["sonuc_score"] = df["Sonuç"].apply(sonuc_score)
df["triaj_score"] = df["Triaj"].map({"Kırmızı Kod": 4, "Sarı Kod": 3, "Yeşil Kod": 2}).fillna(1)

bilinç_map = {
    "Koma": 4, "Semikoma": 4, "Kapalı": 4, "Sedatize": 4,
    "Bulanık": 3, "Konfüze": 3, "Açık": 2
}
df["bilinc_score"] = df["Bilinç"].map(bilinç_map).fillna(1)

nabiz_map = {
    "Alınmıyor": 4, "Filiform": 4, "Aritmik": 3, "Düzenli": 2
}
df["nabiz_score"] = df["Nabız"].map(nabiz_map).fillna(1)

df["tansiyon_score"] = df["Tansiyon"].apply(tansiyon_score)
df["glukoz_score"] = df["Glukoz"].apply(glukoz_score)
df["ates_score"] = df["Ateş"].apply(ates_score)
df["spo2_score"] = df["SPO2"].apply(spo2_score)
df["solunum_score"] = df["Solunum Değeri"].apply(solunum_score)
df["nabiz_deger_score"] = df["Nabız Değeri"].apply(nabiz_deg_score)

# %%
df['nabiz_score'].value_counts()
# Out:
# nabiz_score
# 2.0    2375426
# 1.0    1507105
# 4.0      83029
# 3.0      34195
# Name: count, dtype: int64

# %%
df['case_count']= 1

# %%
df.head()
# Out:
#   KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan  Yaş  \
# 0       524105    ZTB3    2018-08-12 21:08:46        -          -  0.0
# 1       516229    ZTB2    2018-03-12 17:18:46        -          -  0.0
# 2       556760    KÇK8    2018-12-29 20:28:02        -          -  0.0
# 3       539730    KÇK6    2018-12-19 00:05:44        -          -  0.0
# 4       539892    KÇK2    2018-12-19 04:25:54        -          -  0.0
#
#   Adli Vaka Çağrı Nedeni  Sonuç Nakledilen Hastane  ... triaj_score  \
# 0         -      Medikal  Diğer                  -  ...         1.0
# 1         -      Medikal  Diğer                  -  ...         1.0
# 2         -      Medikal  Diğer                  -  ...         1.0
# 3         -      Medikal  Diğer                  -  ...         1.0
# 4         -      Medikal  Diğer                  -  ...         1.0
#
#   bilinc_score nabiz_score tansiyon_score glukoz_score ates_score spo2_score  \
# ...

# %%
df['spo2_score'].value_counts()
# Out:
# spo2_score
# 1    3819491
# 2      99169
# 3      43072
# 4      38023
# Name: count, dtype: int64

# %%
df[df['total_distance']>1000][['Çıkış KM', 'Varış KM', 'Dönüş KM', 'total_distance']].head()
# Out:
# Empty DataFrame
# Columns: [Çıkış KM, Varış KM, Dönüş KM, total_distance]
# Index: []

# %%
df['total_distance'].mean()
# Out:
# 14.78327887046057

# %%
df.columns
# Out:
# Index(['KKM Protokol', 'Ekip No', 'İhbar/Çağrı Tarih Saat', 'Cinsiyet',
#        'Yeni Doğan', 'Yaş', 'Adli Vaka', 'Çağrı Nedeni', 'Sonuç',
#        'Nakledilen Hastane', 'ICD10 TANI\nADI', 'Triaj', 'Bilinç', 'Nabız',
#        'Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat',
#        'Olay Yeri Ayrılış Tarih Saat', 'Hastaneye Varış Tarih Saat',
#        'Hastaneden Ayrılış Tarih Saat', 'Müdahale Süresi Sn',
#        'Hastane Teslim Süresi Sn', 'Çıkış KM', 'Varış KM',
#        'Hastaneye Varış KM', 'Dönüş KM', 'Vakanın Enlemi', 'Vakanın Boylamı',
#        'Tansiyon', 'Glukoz', 'Ateş', 'SPO2', 'Solunum Değeri', 'Nabız Değeri',
#        'Neighbourhood', 'District', 'District Population Density',
#        'case_response_time', 'total_distance', 'cinsiyet_score',
#        'yeni_dogan_score', 'yas_score', 'adli_vaka_score',
#        'cagri_nedeni_score', 'sonuc_score', 'triaj_score', 'bilinc_score',
#        'nabiz_score', 'tansiyon_score', 'glukoz_score', 'ates_score',
# ...

# %%
team_codes= pd.read_csv(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\keywords\team_code_match\eu_team_code.csv")

# %%
team_codes['ASOS']= team_codes['ASOS'].str.strip()

# %%
df= df[df['Ekip No'].isin(team_codes['ASOS'])]

# %%
df= df[~df['Ekip No'].isin(['KÇK6', 'ESY4','BAG5','ZTB3', 'FTH5','BKR6', 'STG7B'])]

# %%
df['ihbar_date'] = pd.to_datetime(df['İhbar/Çağrı Tarih Saat']).dt.date

# %%
daily_counts = df.groupby(['Ekip No', 'ihbar_date']).size().reset_index(name='daily_case_count')

# %%
mean_daily_cases = daily_counts.groupby('Ekip No')['daily_case_count'].mean().rename('mean_daily_case_count')

# %%
df_population_density = pd.read_csv(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\populations\istanbul_population_density.csv")

# %%
df_population_density['Ilce'] = df_population_density['Ilce'].str.strip()

# %%
df_population_density['Nüfus']= df_population_density['Nüfus'].astype(float)

# %%
df_population_density= df_population_density.groupby('Ilce')['Nüfus'].sum().reset_index()

# %%
population_density_dict= df_population_density.set_index('Ilce').to_dict()['Nüfus']

# %%
df['District Population Density']= df['District'].map(population_density_dict)

# %%
df_district_case_counts =df.groupby(['District', 'Ekip No']).agg({'case_count':'sum', 'District Population Density':'mean'}).reset_index().sort_values(by=['District', 'case_count'], ascending=[True, False])

# %%
df_district_case_counts['case_count_percentage'] = df_district_case_counts.groupby('District')['case_count'].transform(lambda x: x / x.sum() * 100)

# %%
df_district_case_counts['teams_population_density'] = df_district_case_counts['District Population Density'] / 100 * df_district_case_counts['case_count_percentage']

# %%
team_population_densities= df_district_case_counts.groupby(['Ekip No']).agg({'case_count': 'sum', 'teams_population_density': 'mean'}).reset_index().sort_values(by='teams_population_density', ascending=False)

# %%
team_population_densities
# Out:
#     Ekip No  case_count  teams_population_density
# 42     BEŞ2        1732              29487.094223
# 142    KÇK1        2727              24212.813773
# 43     BEŞ3        2444              20432.461494
# 200    ŞİŞ4        2504              19475.169232
# 146   KÇK13        2733              16489.192662
# ..      ...         ...                       ...
# 194    ÇTL3         646                904.072103
# 193    ÇTL2         914                869.300106
# 46     BEŞ6         600                836.149494
# 113    EYP7         538                725.066663
# 196    ÇTL5         264                374.959933
#
# [206 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import numpy as np

# %%
df= pd.read_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_final.parquet")

# %%
df.head()
# Out:
#   KKM Protokol Ekip No İhbar/Çağrı Tarih Saat Cinsiyet Yeni Doğan  Yaş  \
# 1       516229    ZTB2    2018-03-12 17:18:46        -          -  0.0
# 2       556760    KÇK8    2018-12-29 20:28:02        -          -  0.0
# 4       539892    KÇK2    2018-12-19 04:25:54        -          -  0.0
# 5       552710    KÇK9    2018-12-27 11:36:58        -          -  0.0
# 6       557861    KÇK7    2018-12-30 15:42:03        -          -  0.0
#
#   Adli Vaka Çağrı Nedeni  Sonuç Nakledilen Hastane  ... bilinc_score  \
# 1         -      Medikal  Diğer                  -  ...          1.0
# 2         -      Medikal  Diğer                  -  ...          1.0
# 4         -      Medikal  Diğer                  -  ...          1.0
# 5         -      Medikal  Diğer                  -  ...          1.0
# 6         -        Diğer  Diğer                  -  ...          1.0
#
#   nabiz_score tansiyon_score glukoz_score ates_score spo2_score solunum_score  \
# ...

# %%
df['season'] = df['İhbar/Çağrı Tarih Saat'].apply(lambda x: 'Winter' if x.month in [12, 1, 2] else ('Spring' if x.month in [3, 4, 5] else ('Summer' if x.month in [6, 7, 8] else 'Autumn')))
df['day']= df['İhbar/Çağrı Tarih Saat'].dt.day_name()

# %%
df.columns
# Out:
# Index(['KKM Protokol', 'Ekip No', 'İhbar/Çağrı Tarih Saat', 'Cinsiyet',
#        'Yeni Doğan', 'Yaş', 'Adli Vaka', 'Çağrı Nedeni', 'Sonuç',
#        'Nakledilen Hastane', 'ICD10 TANI\nADI', 'Triaj', 'Bilinç', 'Nabız',
#        'Vaka Veriliş Tarih Saat', 'Olay Yeri Varış Tarih Saat',
#        'Olay Yeri Ayrılış Tarih Saat', 'Hastaneye Varış Tarih Saat',
#        'Hastaneden Ayrılış Tarih Saat', 'Müdahale Süresi Sn',
#        'Hastane Teslim Süresi Sn', 'Çıkış KM', 'Varış KM',
#        'Hastaneye Varış KM', 'Dönüş KM', 'Vakanın Enlemi', 'Vakanın Boylamı',
#        'Tansiyon', 'Glukoz', 'Ateş', 'SPO2', 'Solunum Değeri', 'Nabız Değeri',
#        'Neighbourhood', 'District', 'District Population Density',
#        'case_response_time', 'total_distance', 'cinsiyet_score',
#        'yeni_dogan_score', 'yas_score', 'adli_vaka_score',
#        'cagri_nedeni_score', 'sonuc_score', 'triaj_score', 'bilinc_score',
#        'nabiz_score', 'tansiyon_score', 'glukoz_score', 'ates_score',
# ...

# %%
def logarithmic_score(value, base=10, scale=1):
    if value <= 0:
        return 0
    return scale * np.log(value + 1) / np.log(base)

for season in df['season'].unique():
    for day in df['day'].unique():
        subset = df[(df['season'] == season) & (df['day'] == day)]
        if not subset.empty:
            df_team_grouped = subset.groupby('Ekip No').agg({
                'total_distance': 'mean',
                'case_response_time': 'mean',
                'yas_score': 'mean',
                'cinsiyet_score': 'mean',
                'yeni_dogan_score': 'mean',
                'adli_vaka_score': 'mean',
                'cagri_nedeni_score': 'mean',
                'sonuc_score': 'mean',
                'triaj_score': 'mean',
                'bilinc_score': 'mean',
                'nabiz_score': 'mean',
                'tansiyon_score': 'mean',
                'glukoz_score': 'mean',
                'ates_score': 'mean',
                'spo2_score': 'mean',
                'solunum_score': 'mean',
                'nabiz_deger_score': 'mean',
                'icd_score': 'mean',
            })

            df_team_grouped = df_team_grouped.merge(mean_daily_cases, left_index=True, right_index=True)
            df_team_grouped= pd.merge(df_team_grouped, team_population_densities, on='Ekip No', how='left', suffixes=('', '_team_density'))
            
            for col in df_team_grouped.columns[1:]:
                new_col= col + '_logarithmic_score'
                df_team_grouped[new_col] = df_team_grouped[col].apply(lambda x: logarithmic_score(x, base=10, scale=1))
                
            for col in df_team_grouped.columns:
                if col.endswith('_logarithmic_score'):
                    new_col = col + '_z_score'
                    df_team_grouped[new_col] = (df_team_grouped[col] - df_team_grouped[col].mean()) / df_team_grouped[col].std()
            
            df_team_grouped['total_score']= df_team_grouped[[col for col in df_team_grouped.columns if col.endswith('_logarithmic_score')]].sum(axis=1)
            df_team_grouped['total_score_z']= (df_team_grouped['total_score'] - df_team_grouped['total_score'].mean()) / df_team_grouped['total_score'].std()
            df_team_grouped= df_team_grouped.sort_values(by='total_score_z', ascending=False).reset_index()

            df_team_grouped.to_excel(rf"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\team_case_intensities\{season}_{day}_total scores.xlsx")

# %%
df_team_grouped = df.groupby('Ekip No').agg({
    'total_distance': 'mean',
    'case_response_time': 'mean',
    'yas_score': 'mean',
    'cinsiyet_score': 'mean',
    'yeni_dogan_score': 'mean',
    'adli_vaka_score': 'mean',
    'cagri_nedeni_score': 'mean',
    'sonuc_score': 'mean',
    'triaj_score': 'mean',
    'bilinc_score': 'mean',
    'nabiz_score': 'mean',
    'tansiyon_score': 'mean',
    'glukoz_score': 'mean',
    'ates_score': 'mean',
    'spo2_score': 'mean',
    'solunum_score': 'mean',
    'nabiz_deger_score': 'mean',
    'icd_score': 'mean',
})

df_team_grouped = df_team_grouped.merge(mean_daily_cases, left_index=True, right_index=True)
df_team_grouped= pd.merge(df_team_grouped, team_population_densities, on='Ekip No', how='left', suffixes=('', '_team_density'))

# %%
df_team_grouped.columns
# Out:
# Index(['Ekip No', 'total_distance', 'case_response_time', 'yas_score',
#        'cinsiyet_score', 'yeni_dogan_score', 'adli_vaka_score',
#        'cagri_nedeni_score', 'sonuc_score', 'triaj_score', 'bilinc_score',
#        'nabiz_score', 'tansiyon_score', 'glukoz_score', 'ates_score',
#        'spo2_score', 'solunum_score', 'nabiz_deger_score', 'icd_score',
#        'mean_daily_case_count', 'case_count', 'teams_population_density'],
#       dtype='object')

# %%
df_team_grouped
# Out:
#     Ekip No  total_distance  case_response_time  yas_score  cinsiyet_score  \
# 0      ARN1       17.438218           16.783090   2.905216        2.317792
# 1      ARN2       32.530534           18.079517   2.876261        2.358513
# 2      ARN3       25.450537           19.557835   2.872930        2.286897
# 3      ARN4       20.865747           18.130833   2.930581        2.344570
# 4      ARN5       44.354258           23.794578   2.913327        2.318781
# ..      ...             ...                 ...        ...             ...
# 201    ŞİŞ5       10.209242           16.759755   2.812465        2.155474
# 202    ŞİŞ6       11.289206           19.014242   2.861665        2.192597
# 203    ŞİŞ7       12.016899           19.527245   2.807957        2.135483
# 204    ŞİŞ8       10.614757           19.424025   2.920241        2.192825
# 205    ŞİŞ9       12.905532           14.269878   2.766620        2.178987
#
# ...

# %%
def logarithmic_score(value, base=10, scale=1):
    if value <= 0:
        return 0
    return scale * np.log(value + 1) / np.log(base)

# %%
for col in df_team_grouped.columns[1:]:
    new_col= col + '_logarithmic_score'
    df_team_grouped[new_col] = df_team_grouped[col].apply(lambda x: logarithmic_score(x, base=10, scale=1))

# %%
df_team_grouped['teams_population_density_logarithmic_score'].min()
# Out:
# 2.56927809538477

# %%
df_team_grouped
# Out:
#     Ekip No  total_distance  case_response_time  yas_score  cinsiyet_score  \
# 0      ARN1       17.438218           16.783090   2.905216        2.317792
# 1      ARN2       32.530534           18.079517   2.876261        2.358513
# 2      ARN3       25.450537           19.557835   2.872930        2.286897
# 3      ARN4       20.865747           18.130833   2.930581        2.344570
# 4      ARN5       44.354258           23.794578   2.913327        2.318781
# ..      ...             ...                 ...        ...             ...
# 201    ŞİŞ5       10.209242           16.759755   2.812465        2.155474
# 202    ŞİŞ6       11.289206           19.014242   2.861665        2.192597
# 203    ŞİŞ7       12.016899           19.527245   2.807957        2.135483
# 204    ŞİŞ8       10.614757           19.424025   2.920241        2.192825
# 205    ŞİŞ9       12.905532           14.269878   2.766620        2.178987
#
# ...

# %%
for col in df_team_grouped.columns:
    if col.endswith('_logarithmic_score'):
        new_col = col + '_z_score'
        df_team_grouped[new_col] = (df_team_grouped[col] - df_team_grouped[col].mean()) / df_team_grouped[col].std()

# %%
df_team_grouped['total_score']= df_team_grouped[[col for col in df_team_grouped.columns if col.endswith('_logarithmic_score')]].sum(axis=1)

# %%
df_team_grouped.sort_values(by='total_score', ascending=False, inplace=True)

# %%
df_team_grouped['total_z_score']= (df_team_grouped['total_score'] - df_team_grouped['total_score'].mean()) / df_team_grouped['total_score'].std()

# %%
df_team_grouped.sort_values(by='total_z_score', ascending=False, inplace=True)

# %%
df_team_grouped.index= df_team_grouped['Ekip No']

# %%
df_team_grouped.loc['ÇTL3']
# Out:
# Ekip No                                                    ÇTL3
# total_distance                                        72.730335
# case_response_time                                    22.027962
# yas_score                                              3.065452
# cinsiyet_score                                         2.356416
#                                                         ...
# mean_daily_case_count_logarithmic_score_z_score       -3.867118
# case_count_logarithmic_score_z_score                  -2.892642
# teams_population_density_logarithmic_score_z_score    -2.550583
# total_score                                           16.406745
# total_z_score                                         -2.134624
# Name: ÇTL3, Length: 66, dtype: object

# %%
df_team_grouped.to_excel(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\team_scores.xlsx", index=False)

# %%
#df_team_grouped['total_score'] = df_team_grouped['total_score'] + df_team_grouped['mean_daily_case_count']

# %%
df_population_density
# Out:
#              Ilce     Nüfus
# 0      Arnavutköy  253014.0
# 1        Ataşehir  423372.0
# 2         Avcılar  435682.0
# 3    Bahçelievler  598454.0
# 4        Bakırköy  222370.0
# 5      Bayrampaşa  274197.0
# 6        Bağcılar  748483.0
# 7      Başakşehir  396665.0
# 8          Beykoz  244164.0
# 9      Beylikdüzü  314662.0
# 10        Beyoğlu  236515.0
# 11       Beşiktaş  185447.0
# 12   Büyükçekmece  240945.0
# 13        Esenler  454569.0
# 14       Esenyurt  846492.0
# 15     Eyüpsultan  377095.0
# 16          Fatih  433650.0
# 17  Gaziosmanpaşa  497959.0
# 18       Güngören  296967.0
# 19        Kadıköy  451453.0
# 20         Kartal  463433.0
# 21      Kağıthane  442694.0
# 22   Küçükçekmece  770392.0
# 23        Maltepe  497586.0
# 24         Pendik  694747.0
# 25     Sancaktepe  400668.0
# 26        Sarıyer  344543.0
# 27        Silivri  155139.0
# 28    Sultanbeyli  329985.0
# 29     Sultangazi  528514.0
# 30          Tuzla  250451.0
# 31    Zeytinburnu  287378.0
# ...

# %%
population_density_dict
# Out:
# {'Zeytinburnu': 2592,
#  'Esenler': 2567,
#  'Güngören': 10184,
#  'Bağcılar': 24596,
#  'Bahçelievler': 34683,
#  'Kağıthane': 38313,
#  'Beyoğlu': 128,
#  'Gaziosmanpaşa': 23816,
#  'Fatih': 135,
#  'Esenyurt': 10461,
#  'Şişli': 2504,
#  'Sultangazi': 6743,
#  'Eyüpsultan': 5179,
#  'Beşiktaş': 3145,
#  'Küçükçekmece': 10461,
#  'Bayrampaşa': 21448,
#  'Maltepe': 7779,
#  'Üsküdar': 1712,
#  'Avcılar': 22496,
#  'Çekmeköy': 2132,
#  'Ümraniye': 3976,
#  'Sancaktepe': 5458,
#  'Pendik': 3414,
#  'Ataşehir': 22254,
#  'Bakırköy': 23785,
#  'Silivri': 1938,
#  'Kartal': 16305,
#  'Kadıköy': 17657,
#  'Sultanbeyli': 18158,
#  'Beylikdüzü': 11644,
#  'Arnavutköy': 5242,
#  'Tuzla': 1903,
#  'Sarıyer': 393,
#  'Büyükçekmece': 1233,
#  'Beykoz': 1283,
#  'Başakşehir': 1269,
#  'Şile': 724,
#  'Çatalca': 2491}

# %%
df_district_case_counts.head()
# Out:
#      District Ekip No  case_count  District Population Density  \
# 0      Adalar    BEŞ6           1                          NaN
# 1  Arnavutköy    ARN1        2322                     253014.0
# 4  Arnavutköy    ARN4        2119                     253014.0
# 6  Arnavutköy    ARN6        1957                     253014.0
# 7  Arnavutköy    ARN7        1727                     253014.0
#
#    case_count_percentage  teams_population_density
# 0             100.000000                       NaN
# 1              16.165414              40900.759398
# 4              14.752158              37325.025480
# 6              13.624339              34471.484127
# 7              12.023113              30420.159983

# %%
df_district_case_counts.to_excel(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\district_case_counts.xlsx", index=False)

# %%
team_population_densities
# Out:
#     Ekip No  case_count  teams_population_density
# 42     BEŞ2        1838              28917.555408
# 142    KÇK1        2828              24161.068015
# 201    ŞİŞ4        2630              19985.700611
# 43     BEŞ3        2564              17027.632494
# 102    ESY5        3707              14348.743936
# ..      ...         ...                       ...
# 46     BEŞ6         636                921.862618
# 195    ÇTL3         671                892.589290
# 194    ÇTL2         960                803.316216
# 113    EYP7         569                736.437174
# 197    ÇTL5         273                369.918159
#
# [207 rows x 3 columns]

# %%
team_population_densities.to_excel(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\team_population_densities.xlsx", index=False)

# %%
pd.merge(df_team_grouped, team_population_densities, on='Ekip No', how='left', suffixes=('', '_team_density'))
# Out:
#     Ekip No  total_distance  case_response_time  yas_score  cinsiyet_score  \
# 0      SLV8       33.965813           14.440356   2.937828        2.324058
# 1      ÇTL4       67.069087           24.479850   3.069253        2.327603
# 2      BŞK6       16.106371           18.983381   2.830885        2.315580
# 3      BÇK7       19.200404           13.454594   3.001049        2.341833
# 4      BDZ6       17.294199           15.804913   3.009305        2.341306
# ..      ...             ...                 ...        ...             ...
# 202    BEŞ5       16.165048           18.515485   2.877813        2.186769
# 203    SRY7       33.505649           23.508995   2.752232        2.130241
# 204    SLV2        6.828099            6.767064   2.859160        2.722391
# 205    ŞİŞ7       12.016899           19.527245   2.807957        2.135483
# 206    SRY5       40.877450           26.519386   2.735085        2.110350
#
# ...

# %%
df_team_grouped.tail(60)
# Out:
#          total_distance  case_response_time  yas_score  cinsiyet_score  \
# Ekip No
# ZTB4           9.850225           17.743066   2.999314        2.308721
# BEY6           9.538734           15.321222   2.908261        2.236198
# GOP2          11.312458           15.047036   2.954346        2.296159
# BYR6          12.015620           15.322541   2.994784        2.270067
# BHC5           7.778615           14.753874   2.997530        2.269151
# STG7B         10.501648           11.172635   2.785560        2.231950
# AVC9          27.915150           19.046107   2.807541        2.309294
# BHC1           8.912791           17.733367   3.011856        2.260141
# BDZ4          16.247562           19.311790   2.911618        2.271906
# FTH9          11.229712           20.000574   2.834995        2.272244
# BEY4          12.691761           17.773102   2.965700        2.261912
# GOP3          13.650439           15.997175   2.968222        2.303186
# ...

# %%
df_team_grouped.to_excel(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\team_performance.xlsx")

# %%
df.to_parquet(r"C:\Users\mkaya\OneDrive\Masaüstü\istanbul112_hidden\data\case_reports\europe\parquet_files\work_file_final.parquet")
